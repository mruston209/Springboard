# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nfl = pd.read_csv('NFL_thru_week_18_with_FE.csv')

# %%
nfl.head()
# Out:
#    Unnamed: 0  index  Week  Year   GID                 Name Pos Team h/a Oppt  \
# 0           0      0     1  2021  1537        Murray, Kyler  QB  ari   a  ten
# 1           1      1     1  2021  1523  Mahomes II, Patrick  QB  kan   h  cle
# 2           2      2     1  2021  1490          Goff, Jared  QB  det   h  sfo
# 3           3      3     1  2021  1465      Winston, Jameis  QB  nor   h  gnb
# 4           4      4     1  2021  1131           Brady, Tom  QB  tam   h  dal
#
#    FD points  FD salary  home_dummy  LastFD  LastSalary  Salary_MA3  LastCMA  \
# 0      34.56     8400.0           0     NaN         NaN         NaN      NaN
# 1      33.28     8800.0           1     NaN         NaN         NaN      NaN
# 2      29.92     6500.0           1     NaN         NaN         NaN      NaN
# 3      29.62     6700.0           1     NaN         NaN         NaN      NaN
# 4      29.16     7800.0           1     NaN         NaN         NaN      NaN
#
#    LastSalaryCMA  FDLast3
# 0            NaN      NaN
# 1            NaN      NaN
# 2            NaN      NaN
# 3            NaN      NaN
# 4            NaN      NaN

# %%
nfl.tail()
# Out:
#       Unnamed: 0  index  Week  Year   GID          Name  Pos Team h/a Oppt  \
# 8020        8020   8020    18  2021  7002       Atlanta  Def  atl   h  nor
# 8021        8021   8021    18  2021  7026   LA Chargers  Def  lac   a  oak
# 8022        8022   8022    18  2021  7023  Philadelphia  Def  phi   h  dal
# 8023        8023   8023    18  2021  7005      Carolina  Def  car   a  tam
# 8024        8024   8024    18  2021  7012     Green Bay  Def  gnb   a  det
#
#       FD points  FD salary  home_dummy  LastFD  LastSalary   Salary_MA3  \
# 8020        0.0     3300.0           1     8.0      3000.0  3366.666667
# 8021       -1.0     4200.0           0    13.0      4000.0  4333.333333
# 8022       -3.0     3700.0           1     6.0      4300.0  4333.333333
# 8023       -3.0     3400.0           0     3.0      3600.0  3433.333333
# 8024       -3.0     4300.0           0     6.0      4700.0  4566.666667
#
#       LastCMA  LastSalaryCMA   FDLast3
# 8020   4.0625        3525.00  4.000000
# 8021   4.9375        3831.25  4.666667
# 8022   7.1250        3937.50  8.333333
# 8023   5.7500        4068.75  2.333333
# 8024   7.5625        4143.75  6.333333

# %%
### nfl.groupby(['Oppt','Pos'])

# %%
tmp = nfl.sort_values('Week').groupby(['Oppt','Pos'])['FD points'].rolling(3, min_periods=1).mean().reset_index()

#tmp = nfl.sort_values('Week').groupby(['Oppt','Pos'])['FD points'].expanding().mean().reset_index()

tmp
# Out:
#      Oppt  Pos  level_2  FD points
# 0     ari  Def      466   0.000000
# 1     ari  Def      919   6.000000
# 2     ari  Def     1408   4.666667
# 3     ari  Def     1885   4.333333
# 4     ari  Def     2340   2.000000
# ...   ...  ...      ...        ...
# 8020  was   WR     7866   3.800000
# 8021  was   WR     7867   1.400000
# 8022  was   WR     7841  -0.100000
# 8023  was   WR     7745   3.200000
# 8024  was   WR     7783   4.533333
#
# [8025 rows x 4 columns]

# %%
nfl.head()
# Out:
#    Unnamed: 0  index  Week  Year   GID                 Name Pos Team h/a Oppt  \
# 0           0      0     1  2021  1537        Murray, Kyler  QB  ari   a  ten
# 1           1      1     1  2021  1523  Mahomes II, Patrick  QB  kan   h  cle
# 2           2      2     1  2021  1490          Goff, Jared  QB  det   h  sfo
# 3           3      3     1  2021  1465      Winston, Jameis  QB  nor   h  gnb
# 4           4      4     1  2021  1131           Brady, Tom  QB  tam   h  dal
#
#    FD points  FD salary  home_dummy  LastFD  LastSalary  Salary_MA3  LastCMA  \
# 0      34.56     8400.0           0     NaN         NaN         NaN      NaN
# 1      33.28     8800.0           1     NaN         NaN         NaN      NaN
# 2      29.92     6500.0           1     NaN         NaN         NaN      NaN
# 3      29.62     6700.0           1     NaN         NaN         NaN      NaN
# 4      29.16     7800.0           1     NaN         NaN         NaN      NaN
#
#    LastSalaryCMA  FDLast3
# 0            NaN      NaN
# 1            NaN      NaN
# 2            NaN      NaN
# 3            NaN      NaN
# 4            NaN      NaN

# %%
tmp[(tmp.Oppt == 'ten') & (tmp.Pos == 'QB')]
### Problem here! D'oh. Need to summarize data first, before this step, I think. Confusing...
# Out:
#      Oppt Pos  level_2  FD points
# 7565  ten  QB        0  34.560000
# 7566  ten  QB      477  28.940000
# 7567  ten  QB      976  21.880000
# 7568  ten  QB     1432  16.586667
# 7569  ten  QB     1895  16.386667
# 7570  ten  QB     2357  23.706667
# 7571  ten  QB     2790  20.393333
# 7572  ten  QB     2793  14.046667
# 7573  ten  QB     3164  10.920000
# 7574  ten  QB     3613  13.026667
# 7575  ten  QB     4014  18.440000
# 7576  ten  QB     4040  13.240000
# 7577  ten  QB     4436  14.580000
# 7578  ten  QB     4905   7.906667
# 7579  ten  QB     4875  13.493333
# 7580  ten  QB     5754   8.813333
# 7581  ten  QB     6158  12.820000
# 7582  ten  QB     6632  10.713333
# 7583  ten  QB     7126   9.033333
# 7584  ten  QB     7116   6.826667
# 7585  ten  QB     7560  10.846667

# %%
nfl[(nfl.Oppt == 'ten') & (nfl.Pos == 'QB') ]
# Out:
#       Unnamed: 0  index  Week  Year   GID                 Name Pos Team h/a  \
# 0              0      0     1  2021  1537        Murray, Kyler  QB  ari   a
# 477          477    477     2  2021  1412      Wilson, Russell  QB  sea   h
# 976          976    976     3  2021  1514        Wentz, Carson  QB  ind   a
# 1432        1432   1432     4  2021  1566         Wilson, Zach  QB  nyj   h
# 1895        1895   1895     5  2021  1565     Lawrence, Trevor  QB  jac   h
# 2357        2357   2357     6  2021  1529          Allen, Josh  QB  buf   a
# 2790        2790   2790     7  2021  1523  Mahomes II, Patrick  QB  kan   a
# 2793        2793   2793     7  2021  1309          Henne, Chad  QB  kan   a
# 3164        3164   3164     8  2021  1514        Wentz, Carson  QB  ind   h
# 3613        3613   3613     9  2021  1340    Stafford, Matthew  QB  lar   h
# 4014        4014   4014    10  2021  1488      Siemian, Trevor  QB  nor   a
# 4040        4040   4040    10  2021  1530         Hill, Taysom  QB  nor   a
# 4436        4436   4436    11  2021  1400        Taylor, Tyrod  QB  hou   a
# 4875        4875   4875    12  2021  1572           Jones, Mac  QB  nwe   h
# 4905        4905   4905    12  2021  1336         Hoyer, Brian  QB  nwe   h
# 5754        5754   5754    14  2021  1565     Lawrence, Trevor  QB  jac   a
# 6158        6158   6158    15  2021  1232  Roethlisberger, Ben  QB  pit   h
# 6632        6632   6632    16  2021  1452     Garoppolo, Jimmy  QB  sfo   a
# 7116        7116   7116    17  2021  1551      Tagovailoa, Tua  QB  mia   a
# 7126        7126   7126    17  2021  1496     Brissett, Jacoby  QB  mia   a
# 7560        7560   7560    18  2021  1574         Mills, Davis  QB  hou   h
#
#      Oppt  FD points  FD salary  home_dummy  LastFD  LastSalary   Salary_MA3  \
# 0     ten      34.56     8400.0           0     NaN         NaN          NaN
# 477   ten      23.32     8500.0           1   27.06      7800.0          NaN
# 976   ten       7.76     7000.0           0   18.58      6700.0  6733.333333
# 1432  ten      18.68     6400.0           1    4.60      6500.0  6466.666667
# 1895  ten      22.72     6500.0           1   17.76      6700.0  6600.000000
# 2357  ten      29.72     8800.0           0   36.50      8800.0  8700.000000
# 2790  ten       8.74     8800.0           0   24.98      9000.0  8833.333333
# 2793  ten       3.68     6000.0           0     NaN         NaN          NaN
# 3164  ten      20.34     7200.0           1   20.30      6700.0  6866.666667
# 3613  ten      15.06     8400.0           1   24.20      8200.0  8233.333333
# 4014  ten      19.92     7000.0           0   15.96      7000.0  6666.666667
# 4040  ten       4.74     7300.0           0    1.72      7000.0  6800.000000
# 4436  ten      19.08     6600.0           0    8.90      6900.0  6766.666667
# 4875  ten      21.50     6800.0           1   11.38      7000.0  6766.666667
# 4905  ten      -0.10     6100.0           1    7.20      6000.0  6033.333333
# 5754  ten       5.04     6300.0           0    6.80      6700.0  6566.666667
# 6158  ten      11.92     6600.0           1   25.82      6800.0  6633.333333
# 6632  ten      15.18     6900.0           0   13.80      6700.0  6766.666667
# 7116  ten       5.30     6700.0           0   11.02      6800.0  6966.666667
# 7126  ten       0.00     6200.0           0    0.00      6100.0  6133.333333
# 7560  ten      27.24     6400.0           1    9.92      6400.0  6466.666667
#
#         LastCMA  LastSalaryCMA    FDLast3
# 0           NaN            NaN        NaN
# 477   27.060000    7800.000000        NaN
# 976   18.460000    6600.000000        NaN
# 1432  10.073333    6500.000000  10.073333
# 1895  14.530000    6750.000000  12.013333
# 2357  25.920000    8300.000000  31.580000
# 2790  26.980000    8750.000000  26.226667
# 2793        NaN            NaN        NaN
# 3164  17.500000    6685.714286  19.966667
# 3613  23.435000    7800.000000  25.866667
# 4014  13.260000    6500.000000        NaN
# 4040   5.350000    6450.000000   7.026667
# 4436  16.346667    6833.333333  16.346667
# 4875  14.149091    6627.272727  12.753333
# 4905   3.253333    6000.000000   3.253333
# 5754  13.221667    6658.333333  11.146667
# 6158  15.720000    6783.333333  18.560000
# 6632  16.121538    6846.153846  17.300000
# 7116  15.769091    6890.909091  14.873333
# 7126   7.632000    6350.000000   2.280000
# 7560  11.643333    6425.000000  14.513333

# %%
tmp2 = nfl.sort_values('Week').groupby(['Oppt','Pos','Week'])['FD points'].sum().reset_index()

tmp2
# Out:
#      Oppt  Pos  Week  FD points
# 0     ari  Def     1        0.0
# 1     ari  Def     2       12.0
# 2     ari  Def     3        2.0
# 3     ari  Def     4       -1.0
# 4     ari  Def     5        5.0
# ...   ...  ...   ...        ...
# 3241  was   WR    14       36.0
# 3242  was   WR    15       24.9
# 3243  was   WR    16       50.4
# 3244  was   WR    17       13.6
# 3245  was   WR    18       13.3
#
# [3246 rows x 4 columns]

# %%
tmp2.head(20)
# Out:
#    Oppt  Pos  Week  FD points
# 0   ari  Def     1        0.0
# 1   ari  Def     2       12.0
# 2   ari  Def     3        2.0
# 3   ari  Def     4       -1.0
# 4   ari  Def     5        5.0
# 5   ari  Def     6       -2.0
# 6   ari  Def     7        7.0
# 7   ari  Def     8        8.0
# 8   ari  Def     9        1.0
# 9   ari  Def    10       12.0
# 10  ari  Def    11        2.0
# 11  ari  Def    13        0.0
# 12  ari  Def    14        8.0
# 13  ari  Def    15        8.0
# 14  ari  Def    16        3.0
# 15  ari  Def    17        1.0
# 16  ari  Def    18        7.0
# 17  ari   PK     1        1.0
# 18  ari   PK     2       13.0
# 19  ari   PK     3        1.0

# %%
nfl.head()
# Out:
#    Unnamed: 0  index  Week  Year   GID                 Name Pos Team h/a Oppt  \
# 0           0      0     1  2021  1537        Murray, Kyler  QB  ari   a  ten
# 1           1      1     1  2021  1523  Mahomes II, Patrick  QB  kan   h  cle
# 2           2      2     1  2021  1490          Goff, Jared  QB  det   h  sfo
# 3           3      3     1  2021  1465      Winston, Jameis  QB  nor   h  gnb
# 4           4      4     1  2021  1131           Brady, Tom  QB  tam   h  dal
#
#    FD points  FD salary  home_dummy  LastFD  LastSalary  Salary_MA3  LastCMA  \
# 0      34.56     8400.0           0     NaN         NaN         NaN      NaN
# 1      33.28     8800.0           1     NaN         NaN         NaN      NaN
# 2      29.92     6500.0           1     NaN         NaN         NaN      NaN
# 3      29.62     6700.0           1     NaN         NaN         NaN      NaN
# 4      29.16     7800.0           1     NaN         NaN         NaN      NaN
#
#    LastSalaryCMA  FDLast3
# 0            NaN      NaN
# 1            NaN      NaN
# 2            NaN      NaN
# 3            NaN      NaN
# 4            NaN      NaN

# %%
nfl.Pos.value_counts()
# Out:
# WR     2763
# RB     1914
# TE     1583
# QB      694
# Def     544
# PK      527
# Name: Pos, dtype: int64

# %%
nfl.shape

nfl[nfl.Pos != 'PK'].shape

nfl = nfl[nfl.Pos != 'PK']

nfl.Pos.value_counts()
# Out:
# WR     2763
# RB     1914
# TE     1583
# QB      694
# Def     544
# Name: Pos, dtype: int64

# %%
nfl[(nfl.Week == 2) & (nfl.Team == 'tam')]
### So, in week 2 Tampa Bay played Atlanta. 
### How many (fantasy) points did ATL give up to QBs last week? To RBs? To WRs? To Def?
# Out:
#      Unnamed: 0  index  Week  Year   GID                Name  Pos Team h/a  \
# 471         471    471     2  2021  1131          Brady, Tom   QB  tam   h
# 509         509    509     2  2021  1381     Gabbert, Blaine   QB  tam   h
# 534         534    534     2  2021  5534  Fournette, Leonard   RB  tam   h
# 561         561    561     2  2021  5617       Jones, Ronald   RB  tam   h
# 570         570    570     2  2021  2889    Bernard, Giovani   RB  tam   h
# 631         631    631     2  2021  5253         Evans, Mike   WR  tam   h
# 649         649    649     2  2021  5579       Godwin, Chris   WR  tam   h
# 716         716    716     2  2021  3474      Brown, Antonio   WR  tam   h
# 737         737    737     2  2021  5846      Johnson, Tyler   WR  tam   h
# 762         762    762     2  2021  5772       Miller, Scott   WR  tam   h
# 766         766    766     2  2021  5600     Mickens, Jaydon   WR  tam   h
# 792         792    792     2  2021  4494     Gronkowski, Rob   TE  tam   h
# 824         824    824     2  2021  4700        Howard, O.J.   TE  tam   h
# 841         841    841     2  2021  4648      Brate, Cameron   TE  tam   h
# 915         915    915     2  2021  7029           Tampa Bay  Def  tam   h
#
#     Oppt  FD points  FD salary  home_dummy  LastFD  LastSalary  Salary_MA3  \
# 471  atl      29.64     8200.0           1   29.16      7800.0         NaN
# 509  atl      -0.30     6000.0           1     NaN         NaN         NaN
# 534  atl       9.60     5900.0           1    8.40      6400.0         NaN
# 561  atl       4.10     5300.0           1   -0.60      5900.0         NaN
# 570  atl       2.60     4600.0           1    2.20      4900.0         NaN
# 631  atl      22.00     6700.0           1    3.90      7600.0         NaN
# 649  atl      14.20     8000.0           1   19.00      7200.0         NaN
# 716  atl       2.20     6400.0           1   21.20      5700.0         NaN
# 737  atl       1.00     4500.0           1    0.00      4600.0         NaN
# 762  atl       0.00     4800.0           1    0.00      4800.0         NaN
# 766  atl       0.00     4500.0           1    0.00      4500.0         NaN
# 792  atl      17.90     5800.0           1   25.00      5200.0         NaN
# 824  atl       2.60     4700.0           1    0.00      4900.0         NaN
# 841  atl       1.30     4300.0           1    0.00      4500.0         NaN
# 915  atl      19.00     4500.0           1    2.00      4000.0         NaN
#
#      LastCMA  LastSalaryCMA  FDLast3
# 471    29.16         7800.0      NaN
# 509      NaN            NaN      NaN
# 534     8.40         6400.0      NaN
# 561    -0.60         5900.0      NaN
# 570     2.20         4900.0      NaN
# 631     3.90         7600.0      NaN
# 649    19.00         7200.0      NaN
# 716    21.20         5700.0      NaN
# 737     0.00         4600.0      NaN
# 762     0.00         4800.0      NaN
# 766     0.00         4500.0      NaN
# 792    25.00         5200.0      NaN
# 824     0.00         4900.0      NaN
# 841     0.00         4500.0      NaN
# 915     2.00         4000.0      NaN

# %%
tmp2.head()
# Out:
#   Oppt  Pos  Week  FD points
# 0  ari  Def     1        0.0
# 1  ari  Def     2       12.0
# 2  ari  Def     3        2.0
# 3  ari  Def     4       -1.0
# 4  ari  Def     5        5.0

# %%
tmp2[(tmp2.Week==2)&(tmp2.Oppt=='atl')]

tmp2[(tmp2.Week==1)&(tmp2.Oppt=='atl')]

# nfl[(nfl.Week==1)&(nfl.Oppt=='atl')].groupby('Pos')['FD points'].sum()
# Out:
#     Oppt  Pos  Week  FD points
# 102  atl  Def     1      10.00
# 119  atl   PK     1       7.00
# 136  atl   QB     1      28.76
# 153  atl   RB     1      26.60
# 170  atl   TE     1      16.60
# 187  atl   WR     1      33.80

# %%
tmp2 = tmp2[tmp2.Pos != 'PK']

tmp2
# Out:
#      Oppt  Pos  Week  FD points
# 0     ari  Def     1        0.0
# 1     ari  Def     2       12.0
# 2     ari  Def     3        2.0
# 3     ari  Def     4       -1.0
# 4     ari  Def     5        5.0
# ...   ...  ...   ...        ...
# 3241  was   WR    14       36.0
# 3242  was   WR    15       24.9
# 3243  was   WR    16       50.4
# 3244  was   WR    17       13.6
# 3245  was   WR    18       13.3
#
# [2720 rows x 4 columns]

# %%
tmp3 = tmp2.sort_values('Week').groupby(['Oppt','Pos'])['FD points'].rolling(3, min_periods=1).mean().reset_index()

tmp3
# Out:
#      Oppt  Pos  level_2  FD points
# 0     ari  Def        0   0.000000
# 1     ari  Def        1   6.000000
# 2     ari  Def        2   4.666667
# 3     ari  Def        3   4.333333
# 4     ari  Def        4   2.000000
# ...   ...  ...      ...        ...
# 2715  was   WR     3241  28.433333
# 2716  was   WR     3242  28.533333
# 2717  was   WR     3243  37.100000
# 2718  was   WR     3244  29.633333
# 2719  was   WR     3245  25.766667
#
# [2720 rows x 4 columns]

# %%
tmp2 = tmp2.reset_index()
tmp2
# Out:
#       index Oppt  Pos  Week  FD points
# 0         0  ari  Def     1        0.0
# 1         1  ari  Def     2       12.0
# 2         2  ari  Def     3        2.0
# 3         3  ari  Def     4       -1.0
# 4         4  ari  Def     5        5.0
# ...     ...  ...  ...   ...        ...
# 2715   3241  was   WR    14       36.0
# 2716   3242  was   WR    15       24.9
# 2717   3243  was   WR    16       50.4
# 2718   3244  was   WR    17       13.6
# 2719   3245  was   WR    18       13.3
#
# [2720 rows x 5 columns]

# %%
tmp3
tmp3.rename(columns={'level_2':'index','FD points':'OpptAvg3'}, inplace=True)
tmp3
### tmp4 = tmp3['index','OpptAvg3']
# Out:
#      Oppt  Pos  index   OpptAvg3
# 0     ari  Def      0   0.000000
# 1     ari  Def      1   6.000000
# 2     ari  Def      2   4.666667
# 3     ari  Def      3   4.333333
# 4     ari  Def      4   2.000000
# ...   ...  ...    ...        ...
# 2715  was   WR   3241  28.433333
# 2716  was   WR   3242  28.533333
# 2717  was   WR   3243  37.100000
# 2718  was   WR   3244  29.633333
# 2719  was   WR   3245  25.766667
#
# [2720 rows x 4 columns]

# %%
###tmp4 = tmp2.merge(tmp3, left_on='index', right_on='index')
tmp4 = tmp2.merge(tmp3)

tmp4
# Out:
#       index Oppt  Pos  Week  FD points   OpptAvg3
# 0         0  ari  Def     1        0.0   0.000000
# 1         1  ari  Def     2       12.0   6.000000
# 2         2  ari  Def     3        2.0   4.666667
# 3         3  ari  Def     4       -1.0   4.333333
# 4         4  ari  Def     5        5.0   2.000000
# ...     ...  ...  ...   ...        ...        ...
# 2715   3241  was   WR    14       36.0  28.433333
# 2716   3242  was   WR    15       24.9  28.533333
# 2717   3243  was   WR    16       50.4  37.100000
# 2718   3244  was   WR    17       13.6  29.633333
# 2719   3245  was   WR    18       13.3  25.766667
#
# [2720 rows x 6 columns]

# %%
tmp4[(tmp4.Pos=='QB') & (tmp4.Oppt=='tam')]

# tmp4.to_csv('tmp4.csv') ### To check in a spreadsheet- and yeah, looks correct!
# Out:
#       index Oppt Pos  Week  FD points   OpptAvg3
# 2482   2975  tam  QB     1      28.42  28.420000
# 2483   2976  tam  QB     2      19.30  23.860000
# 2484   2977  tam  QB     3      29.52  25.746667
# 2485   2978  tam  QB     4      17.90  22.240000
# 2486   2979  tam  QB     5      16.00  21.140000
# 2487   2980  tam  QB     6      26.00  19.966667
# 2488   2981  tam  QB     7       4.16  15.386667
# 2489   2982  tam  QB     8      20.80  16.986667
# 2490   2983  tam  QB    10      15.74  13.566667
# 2491   2984  tam  QB    11       9.68  15.406667
# 2492   2985  tam  QB    12      22.34  15.920000
# 2493   2986  tam  QB    13      12.08  14.700000
# 2494   2987  tam  QB    14      36.22  23.546667
# 2495   2988  tam  QB    15       9.46  19.253333
# 2496   2989  tam  QB    16      14.34  20.006667
# 2497   2990  tam  QB    17      13.36  12.386667
# 2498   2991  tam  QB    18      15.66  14.453333

# %%
tmp5 = tmp4

tmp5['Week'] = (tmp5['Week'] + 1)

tmp5.rename(columns={'FD points':'OpptLast'}, inplace=True)

tmp5
# Out:
#       index Oppt  Pos  Week  OpptLast   OpptAvg3
# 0         0  ari  Def     2       0.0   0.000000
# 1         1  ari  Def     3      12.0   6.000000
# 2         2  ari  Def     4       2.0   4.666667
# 3         3  ari  Def     5      -1.0   4.333333
# 4         4  ari  Def     6       5.0   2.000000
# ...     ...  ...  ...   ...       ...        ...
# 2715   3241  was   WR    15      36.0  28.433333
# 2716   3242  was   WR    16      24.9  28.533333
# 2717   3243  was   WR    17      50.4  37.100000
# 2718   3244  was   WR    18      13.6  29.633333
# 2719   3245  was   WR    19      13.3  25.766667
#
# [2720 rows x 6 columns]

# %%
nfl.head()

nfl.shape  ### 7498 rows!

nfl2 = nfl.merge(tmp5, how='left', on=['Oppt','Pos','Week'] )

nfl2
# Out:
#       Unnamed: 0  index_x  Week  Year   GID                 Name  Pos Team  \
# 0              0        0     1  2021  1537        Murray, Kyler   QB  ari
# 1              1        1     1  2021  1523  Mahomes II, Patrick   QB  kan
# 2              2        2     1  2021  1490          Goff, Jared   QB  det
# 3              3        3     1  2021  1465      Winston, Jameis   QB  nor
# 4              4        4     1  2021  1131           Brady, Tom   QB  tam
# ...          ...      ...   ...   ...   ...                  ...  ...  ...
# 7493        8020     8020    18  2021  7002              Atlanta  Def  atl
# 7494        8021     8021    18  2021  7026          LA Chargers  Def  lac
# 7495        8022     8022    18  2021  7023         Philadelphia  Def  phi
# 7496        8023     8023    18  2021  7005             Carolina  Def  car
# 7497        8024     8024    18  2021  7012            Green Bay  Def  gnb
#
#      h/a Oppt  ...  home_dummy  LastFD  LastSalary   Salary_MA3  LastCMA  \
# 0      a  ten  ...           0     NaN         NaN          NaN      NaN
# 1      h  cle  ...           1     NaN         NaN          NaN      NaN
# 2      h  sfo  ...           1     NaN         NaN          NaN      NaN
# 3      h  gnb  ...           1     NaN         NaN          NaN      NaN
# 4      h  dal  ...           1     NaN         NaN          NaN      NaN
# ...   ..  ...  ...         ...     ...         ...          ...      ...
# 7493   h  nor  ...           1     8.0      3000.0  3366.666667   4.0625
# 7494   a  oak  ...           0    13.0      4000.0  4333.333333   4.9375
# 7495   h  dal  ...           1     6.0      4300.0  4333.333333   7.1250
# 7496   a  tam  ...           0     3.0      3600.0  3433.333333   5.7500
# 7497   a  det  ...           0     6.0      4700.0  4566.666667   7.5625
#
#       LastSalaryCMA   FDLast3  index_y  OpptLast   OpptAvg3
# 0               NaN       NaN      NaN       NaN        NaN
# 1               NaN       NaN      NaN       NaN        NaN
# 2               NaN       NaN      NaN       NaN        NaN
# 3               NaN       NaN      NaN       NaN        NaN
# 4               NaN       NaN      NaN       NaN        NaN
# ...             ...       ...      ...       ...        ...
# 7493        3525.00  4.000000   2044.0       3.0  11.333333
# 7494        3831.25  4.666667   2449.0       6.0   7.333333
# 7495        3937.50  8.333333    825.0       3.0   2.333333
# 7496        4068.75  2.333333   2956.0       2.0   6.333333
# 7497        4143.75  6.333333   1026.0       5.0   3.666667
#
# [7498 rows x 22 columns]

# %%
nfl2[(nfl2.Week == 10) & (nfl2.Team == 'den') ]
# Out:
#       Unnamed: 0  index_x  Week  Year   GID                 Name  Pos Team  \
# 3767        4031     4031    10  2021  1439   Bridgewater, Teddy   QB  den
# 3814        4078     4078    10  2021  2991       Gordon, Melvin   RB  den
# 3827        4091     4091    10  2021  5905    Williams, Javonte   RB  den
# 3878        4142     4142    10  2021  5721    Crockett, Damarea   RB  den
# 3921        4185     4185    10  2021  5832         Jeudy, Jerry   WR  den
# 3939        4203     4203    10  2021  5637    Sutton, Courtland   WR  den
# 3952        4216     4216    10  2021  5651         Patrick, Tim   WR  den
# 3985        4249     4249    10  2021  5862     Cleveland, Tyrie   WR  den
# 4003        4267     4267    10  2021  5765     Spencer, Diontae   WR  den
# 4007        4271     4271    10  2021  1561      Hinton, Kendall   WR  den
# 4036        4300     4300    10  2021  4789  Okwuegbunam, Albert   TE  den
# 4037        4301     4301    10  2021  4748           Fant, Noah   TE  den
# 4081        4345     4345    10  2021  4761         Beck, Andrew   TE  den
# 4096        4360     4360    10  2021  4726        Saubert, Eric   TE  den
# 4126        4417     4417    10  2021  7010               Denver  Def  den
#
#      h/a Oppt  ...  home_dummy  LastFD  LastSalary   Salary_MA3    LastCMA  \
# 3767   h  phi  ...           1   21.86      7100.0  7100.000000  16.713333
# 3814   h  phi  ...           1   16.50      6400.0  6233.333333  12.011111
# 3827   h  phi  ...           1   11.10      5800.0  5833.333333   9.011111
# 3878   h  phi  ...           1    0.00      4500.0  4500.000000   0.100000
# 3921   h  phi  ...           1    9.90      5800.0  6000.000000   8.666667
# 3939   h  phi  ...           1    3.40      6700.0  6800.000000  10.366667
# 3952   h  phi  ...           1   16.50      5600.0  5800.000000  10.211111
# 3985   h  phi  ...           1    0.00      4500.0  4500.000000   0.000000
# 4003   h  phi  ...           1    0.00      4500.0  4500.000000   0.025000
# 4007   h  phi  ...           1    4.50      4600.0  4633.333333   3.312500
# 4036   h  phi  ...           1    4.50      4500.0  4566.666667   3.933333
# 4037   h  phi  ...           1    1.80      5800.0  5833.333333   8.562500
# 4081   h  phi  ...           1    0.00      4000.0  4000.000000   0.000000
# 4096   h  phi  ...           1    1.10      4200.0  4300.000000   0.900000
# 4126   h  phi  ...           1    7.00      3400.0  3833.333333   7.888889
#
#       LastSalaryCMA       FDLast3  index_y  OpptLast   OpptAvg3
# 3767    6911.111111  1.642000e+01   2576.0     31.64  20.513333
# 3814    5988.888889  1.480000e+01   2593.0     11.30  24.100000
# 3827    5733.333333  1.036667e+01   2593.0     11.30  24.100000
# 3878    4500.000000  0.000000e+00   2593.0     11.30  24.100000
# 3921    5766.666667  8.666667e+00   2627.0     29.70  22.266667
# 3939    6488.888889  5.900000e+00   2627.0     29.70  22.266667
# 3952    5755.555556  9.000000e+00   2627.0     29.70  22.266667
# 3985    4500.000000  0.000000e+00   2627.0     29.70  22.266667
# 4003    4512.500000  0.000000e+00   2627.0     29.70  22.266667
# 4007    5650.000000  2.333333e+00   2627.0     29.70  22.266667
# 4036    4533.333333  3.666667e+00   2610.0     32.10  20.333333
# 4037    5800.000000  9.466667e+00   2610.0     32.10  20.333333
# 4081    4000.000000  1.093570e-14   2610.0     32.10  20.333333
# 4096    4088.888889  6.333333e-01   2610.0     32.10  20.333333
# 4126    4300.000000  9.333333e+00   2544.0      1.00   1.000000
#
# [15 rows x 22 columns]

# %%
nfl2.drop(columns=['index_x','index_y','Unnamed: 0'], inplace=True)

# %%
nfl2.shape
# Out:
# (7498, 19)

# %%
nfl2.head()
# Out:
#    Week  Year   GID                 Name Pos Team h/a Oppt  FD points  \
# 0     1  2021  1537        Murray, Kyler  QB  ari   a  ten      34.56
# 1     1  2021  1523  Mahomes II, Patrick  QB  kan   h  cle      33.28
# 2     1  2021  1490          Goff, Jared  QB  det   h  sfo      29.92
# 3     1  2021  1465      Winston, Jameis  QB  nor   h  gnb      29.62
# 4     1  2021  1131           Brady, Tom  QB  tam   h  dal      29.16
#
#    FD salary  home_dummy  LastFD  LastSalary  Salary_MA3  LastCMA  \
# 0     8400.0           0     NaN         NaN         NaN      NaN
# 1     8800.0           1     NaN         NaN         NaN      NaN
# 2     6500.0           1     NaN         NaN         NaN      NaN
# 3     6700.0           1     NaN         NaN         NaN      NaN
# 4     7800.0           1     NaN         NaN         NaN      NaN
#
#    LastSalaryCMA  FDLast3  OpptLast  OpptAvg3
# 0            NaN      NaN       NaN       NaN
# 1            NaN      NaN       NaN       NaN
# 2            NaN      NaN       NaN       NaN
# 3            NaN      NaN       NaN       NaN
# 4            NaN      NaN       NaN       NaN

# %%
nfl3 = nfl2.dropna()

nfl3.shape
# Out:
# (5109, 19)

# %%
nfl3.head()
# Out:
#       Week  Year   GID                 Name Pos Team h/a Oppt  FD points  \
# 1322     4  2021  1524         Darnold, Sam  QB  car   a  dal      33.54
# 1323     4  2021  1523  Mahomes II, Patrick  QB  kan   a  phi      32.72
# 1324     4  2021  1301           Ryan, Matt  QB  atl   h  was      29.02
# 1325     4  2021  1554         Hurts, Jalen  QB  phi   h  kan      28.18
# 1326     4  2021  1487     Heinicke, Taylor  QB  was   a  atl      27.90
#
#       FD salary  home_dummy  LastFD  LastSalary   Salary_MA3    LastCMA  \
# 1322     7200.0           0   25.26      7100.0  6966.666667  21.406667
# 1323     8700.0           0   24.90      8700.0  8666.666667  27.733333
# 1324     6700.0           1   15.62      7100.0  6833.333333  14.093333
# 1325     7900.0           1   22.54      8200.0  7966.666667  24.366667
# 1326     7400.0           0   22.88      6800.0  6966.666667  18.166667
#
#       LastSalaryCMA    FDLast3  OpptLast   OpptAvg3
# 1322    6733.333333  21.406667     22.54  22.806667
# 1323    8700.000000  27.733333     20.12  15.680000
# 1324    7033.333333  14.093333     39.16  27.666667
# 1325    7866.666667  24.366667     30.84  26.246667
# 1326    6666.666667  18.166667     16.54  24.880000

# %%
nfl2[nfl2.Name == 'Allen, Josh']
# Out:
#       Week  Year   GID         Name Pos Team h/a Oppt  FD points  FD salary  \
# 20       1  2021  1529  Allen, Josh  QB  buf   h  pit      17.20     8100.0
# 457      2  2021  1529  Allen, Josh  QB  buf   a  mia      17.66     8100.0
# 884      3  2021  1529  Allen, Josh  QB  buf   h  was      37.22     8000.0
# 1334     4  2021  1529  Allen, Josh  QB  buf   h  hou      21.02     8500.0
# 1767     5  2021  1529  Allen, Josh  QB  buf   a  kan      36.50     8800.0
# 2202     6  2021  1529  Allen, Josh  QB  buf   a  ten      29.72     8800.0
# 2946     8  2021  1529  Allen, Josh  QB  buf   h  mia      29.46     8800.0
# 3380     9  2021  1529  Allen, Josh  QB  buf   a  jac      11.56     9000.0
# 3749    10  2021  1529  Allen, Josh  QB  buf   a  nyj      21.94     8700.0
# 4147    11  2021  1529  Allen, Josh  QB  buf   h  ind      18.16     8800.0
# 4549    12  2021  1529  Allen, Josh  QB  buf   a  nor      28.70     8800.0
# 4984    13  2021  1529  Allen, Josh  QB  buf   h  nwe      11.70     8800.0
# 5351    14  2021  1529  Allen, Josh  QB  buf   a  tam      36.22     8800.0
# 5745    15  2021  1529  Allen, Josh  QB  buf   h  car      21.80     8700.0
# 6188    16  2021  1529  Allen, Josh  QB  buf   a  nwe      30.96     8500.0
# 6627    17  2021  1529  Allen, Josh  QB  buf   h  atl      23.90     8800.0
# 7069    18  2021  1529  Allen, Josh  QB  buf   h  nyj      23.86     8800.0
#
#       home_dummy  LastFD  LastSalary   Salary_MA3    LastCMA  LastSalaryCMA  \
# 20             1     NaN         NaN          NaN        NaN            NaN
# 457            0   17.20      8100.0          NaN  17.200000    8100.000000
# 884            1   17.66      8100.0  8066.666667  17.430000    8100.000000
# 1334           1   37.22      8000.0  8200.000000  24.026667    8066.666667
# 1767           0   21.02      8500.0  8433.333333  23.275000    8175.000000
# 2202           0   36.50      8800.0  8700.000000  25.920000    8300.000000
# 2946           1   29.72      8800.0  8800.000000  26.553333    8383.333333
# 3380           0   29.46      8800.0  8866.666667  26.968571    8442.857143
# 3749           0   11.56      9000.0  8833.333333  25.042500    8512.500000
# 4147           1   21.94      8700.0  8833.333333  24.697778    8533.333333
# 4549           0   18.16      8800.0  8766.666667  24.044000    8560.000000
# 4984           1   28.70      8800.0  8800.000000  24.467273    8581.818182
# 5351           0   11.70      8800.0  8800.000000  23.403333    8600.000000
# 5745           1   36.22      8800.0  8766.666667  24.389231    8615.384615
# 6188           0   21.80      8700.0  8666.666667  24.204286    8621.428571
# 6627           1   30.96      8500.0  8666.666667  24.654667    8613.333333
# 7069           1   23.90      8800.0  8700.000000  24.607500    8625.000000
#
#         FDLast3  OpptLast   OpptAvg3
# 20          NaN       NaN        NaN
# 457         NaN     15.24  15.240000
# 884         NaN     29.46  21.920000
# 1334  24.026667     25.26  21.953333
# 1767  25.300000     28.18  31.093333
# 2202  31.580000     22.72  16.386667
# 2946  29.080000     18.44  24.526667
# 3380  31.893333     22.60  19.980000
# 3749  23.580000     24.28  23.526667
# 4147  20.986667      9.78  22.053333
# 4549  17.220000     30.78  26.073333
# 4984  22.933333      9.12   6.866667
# 5351  19.520000     12.08  14.700000
# 5745  25.540000     11.90  16.080000
# 6188  23.240000      6.98   9.266667
# 6627  29.660000     10.48  14.866667
# 7069  25.553333     27.40  18.746667

# %%
# nfl3.append( ( pd.get_dummies(nfl3.Pos) ) )

nfl3 = pd.get_dummies(nfl3, columns=['Pos'], prefix='', prefix_sep='')

nfl3.shape
# Out:
# (5109, 23)

# %%
nfl3.tail()

y = nfl3['FD points']

X = nfl3[['Week','FD salary','home_dummy','LastFD','LastSalary','Salary_MA3','LastCMA','LastSalaryCMA','FDLast3','OpptLast','OpptAvg3','Def','QB','RB','TE','WR']]

# %%
X.head()
# Out:
#       Week  FD salary  home_dummy  LastFD  LastSalary   Salary_MA3    LastCMA  \
# 1322     4     7200.0           0   25.26      7100.0  6966.666667  21.406667
# 1323     4     8700.0           0   24.90      8700.0  8666.666667  27.733333
# 1324     4     6700.0           1   15.62      7100.0  6833.333333  14.093333
# 1325     4     7900.0           1   22.54      8200.0  7966.666667  24.366667
# 1326     4     7400.0           0   22.88      6800.0  6966.666667  18.166667
#
#       LastSalaryCMA    FDLast3  OpptLast   OpptAvg3  Def  QB  RB  TE  WR
# 1322    6733.333333  21.406667     22.54  22.806667    0   1   0   0   0
# 1323    8700.000000  27.733333     20.12  15.680000    0   1   0   0   0
# 1324    7033.333333  14.093333     39.16  27.666667    0   1   0   0   0
# 1325    7866.666667  24.366667     30.84  26.246667    0   1   0   0   0
# 1326    6666.666667  18.166667     16.54  24.880000    0   1   0   0   0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators = 100, random_state = 0)
 
# fit the regressor with x and y training data
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = rf.predict(X_train)

# %%
rf.score(X_train, y_train)
# Out:
# 0.9179015963077737

# %%
plt.scatter( y_train, y_pred)

# %%
y_test_pred = rf.predict(X_test)

plt.scatter( y_test, y_test_pred )

# %%
rf.score( X_test, y_test)
# Out:
# 0.43335909536429384

# %%
### Linear regression ?
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

linreg = linear_model.LinearRegression()

linreg.fit(X_train, y_train)

y_pred = linreg.predict( X_test )

# %%
plt.scatter( y_test, y_pred )

# %%
r2_score( y_test, y_pred )
# Out:
# 0.4522148897343282

# %%
y_train_pred = linreg.predict( X_train)

plt.scatter( y_train, y_train_pred )

# %%
r2_score( y_train, y_train_pred)
# Out:
# 0.443930489992603

# %%
np.corrcoef( y_train, y_train_pred )
# Out:
# array([[1.        , 0.66628109],
#        [0.66628109, 1.        ]])

# %%
np.corrcoef( y_test, y_pred )
# Out:
# array([[1.        , 0.67253455],
#        [0.67253455, 1.        ]])

# %%
### What if we took the first 10 weeks as the training data, and then week 11 as the test data?
nfl3.head()
# Out:
#       Week  Year   GID                 Name Team h/a Oppt  FD points  \
# 1322     4  2021  1524         Darnold, Sam  car   a  dal      33.54
# 1323     4  2021  1523  Mahomes II, Patrick  kan   a  phi      32.72
# 1324     4  2021  1301           Ryan, Matt  atl   h  was      29.02
# 1325     4  2021  1554         Hurts, Jalen  phi   h  kan      28.18
# 1326     4  2021  1487     Heinicke, Taylor  was   a  atl      27.90
#
#       FD salary  home_dummy  ...    LastCMA  LastSalaryCMA    FDLast3  \
# 1322     7200.0           0  ...  21.406667    6733.333333  21.406667
# 1323     8700.0           0  ...  27.733333    8700.000000  27.733333
# 1324     6700.0           1  ...  14.093333    7033.333333  14.093333
# 1325     7900.0           1  ...  24.366667    7866.666667  24.366667
# 1326     7400.0           0  ...  18.166667    6666.666667  18.166667
#
#       OpptLast   OpptAvg3  Def  QB  RB  TE  WR
# 1322     22.54  22.806667    0   1   0   0   0
# 1323     20.12  15.680000    0   1   0   0   0
# 1324     39.16  27.666667    0   1   0   0   0
# 1325     30.84  26.246667    0   1   0   0   0
# 1326     16.54  24.880000    0   1   0   0   0
#
# [5 rows x 23 columns]

# %%
thruweek10 = nfl3[nfl3.Week <= 10]

week11 = nfl3[nfl3.Week == 11]

# %%
thruweek10.head()
thruweek10.columns
# Out:
# Index(['Week', 'Year', 'GID', 'Name', 'Team', 'h/a', 'Oppt', 'FD points',
#        'FD salary', 'home_dummy', 'LastFD', 'LastSalary', 'Salary_MA3',
#        'LastCMA', 'LastSalaryCMA', 'FDLast3', 'OpptLast', 'OpptAvg3', 'Def',
#        'QB', 'RB', 'TE', 'WR'],
#       dtype='object')

# %%
y_train = thruweek10['FD points']

cols = ['Week','FD salary','home_dummy','LastFD','LastSalary','FDLast3','Salary_MA3','LastCMA','LastSalaryCMA'\
        ,'OpptLast','OpptAvg3','Def','QB','RB','TE','WR']

X_train = thruweek10[cols]


y_test = week11['FD points']
X_test = week11[cols]

names11 = week11['Name']

# %%
linreg.fit(X_train, y_train)

y_pred = linreg.predict( X_test )

# %%
plt.scatter( y_test, y_pred)

# %%
np.corrcoef( y_test, y_pred)
# Out:
# array([[1.        , 0.69368932],
#        [0.69368932, 1.        ]])

# %%
y_train_pred = linreg.predict( X_train )

plt.scatter( y_train, y_train_pred )

np.corrcoef( y_train, y_train_pred )
# Out:
# array([[1.       , 0.6828044],
#        [0.6828044, 1.       ]])

# %%
X_test.head()
# Out:
#       Week  FD salary  home_dummy  LastFD  LastSalary    FDLast3   Salary_MA3  \
# 4135    11     7700.0           1   13.00      8000.0  20.153333  7766.666667
# 4136    11     7700.0           0   11.48      7800.0  17.266667  7733.333333
# 4137    11     7700.0           1   19.42      7700.0  15.773333  7733.333333
# 4138    11     7000.0           0   19.92      7000.0  15.480000  7000.000000
# 4140    11     7400.0           1   17.46      7600.0  17.400000  7466.666667
#
#         LastCMA  LastSalaryCMA  OpptLast   OpptAvg3  Def  QB  RB  TE  WR
# 4135  22.055556    7722.222222      4.56  11.066667    0   1   0   0   0
# 4136  18.782222    7822.222222     13.00  21.280000    0   1   0   0   0
# 4137  22.206000    8010.000000     18.62  24.880000    0   1   0   0   0
# 4138  15.480000    6666.666667      9.04  16.720000    0   1   0   0   0
# 4140  19.851111    7444.444444      7.64   9.713333    0   1   0   0   0

# %%
testDF =  X_test[ ['Week','FD salary','Def','QB','RB','TE','WR'] ]

testDF['Name'] = names11

testDF['FD pred'] = np.round(y_pred,2)

testDF['FD actual'] = y_test

testDF.head()
testDF.tail()
# Out:
# <ipython-input-58-9c48052e6bb7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testDF['Name'] = names11
# <ipython-input-58-9c48052e6bb7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testDF['FD pred'] = np.round(y_pred,2)
# <ipython-input-58-9c48052e6bb7>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testDF['FD actual'] = y_test
#       Week  FD salary  Def  QB  RB  TE  WR         Name  FD pred  FD actual
# 4543    11     4000.0    1   0   0   0   0    Green Bay     6.29        1.0
# 4544    11     3500.0    1   0   0   0   0   Washington     4.67        1.0
# 4545    11     3400.0    1   0   0   0   0    Minnesota     4.58        1.0
# 4547    11     4200.0    1   0   0   0   0  LA Chargers     4.93       -1.0
# 4548    11     4500.0    1   0   0   0   0      Buffalo     7.77       -4.0

# %%
testDF[testDF.Def == 1]
# Out:
#       Week  FD salary  Def  QB  RB  TE  WR           Name  FD pred  FD actual
# 4519    11     4800.0    1   0   0   0   0    New England     8.70       28.0
# 4520    11     3000.0    1   0   0   0   0        Houston     2.63       16.0
# 4521    11     3300.0    1   0   0   0   0    Kansas City     3.94       15.0
# 4523    11     3900.0    1   0   0   0   0   Philadelphia     5.29       11.0
# 4524    11     3500.0    1   0   0   0   0        Detroit     2.85       11.0
# 4525    11     4900.0    1   0   0   0   0  San Francisco     7.80       11.0
# 4526    11     3600.0    1   0   0   0   0     Cincinnati     4.02       10.0
# 4527    11     3200.0    1   0   0   0   0   Indianapolis     5.06       10.0
# 4528    11     3500.0    1   0   0   0   0        Chicago     4.60        9.0
# 4530    11     3700.0    1   0   0   0   0         Dallas     6.04        8.0
# 4531    11     5000.0    1   0   0   0   0      Cleveland     7.00        8.0
# 4532    11     4300.0    1   0   0   0   0        Arizona     7.09        8.0
# 4533    11     3100.0    1   0   0   0   0        Atlanta     2.63        6.0
# 4534    11     4100.0    1   0   0   0   0       Carolina     6.74        5.0
# 4535    11     4800.0    1   0   0   0   0          Miami     7.09        5.0
# 4537    11     4400.0    1   0   0   0   0    New Orleans     6.90        4.0
# 4538    11     3800.0    1   0   0   0   0     New York J     3.43        2.0
# 4539    11     3700.0    1   0   0   0   0        Seattle     4.43        2.0
# 4540    11     4000.0    1   0   0   0   0     Pittsburgh     6.26        2.0
# 4541    11     3400.0    1   0   0   0   0     New York G     4.67        2.0
# 4542    11     3400.0    1   0   0   0   0   Jacksonville     3.66        1.0
# 4543    11     4000.0    1   0   0   0   0      Green Bay     6.29        1.0
# 4544    11     3500.0    1   0   0   0   0     Washington     4.67        1.0
# 4545    11     3400.0    1   0   0   0   0      Minnesota     4.58        1.0
# 4547    11     4200.0    1   0   0   0   0    LA Chargers     4.93       -1.0
# 4548    11     4500.0    1   0   0   0   0        Buffalo     7.77       -4.0

# %%
thruweek10[thruweek10.Name == 'New England']
# Out:
#       Week  Year   GID         Name Team h/a Oppt  FD points  FD salary  \
# 1754     4  2021  7018  New England  nwe   h  tam        2.0     3700.0
# 2189     5  2021  7018  New England  nwe   a  hou        5.0     5000.0
# 2580     6  2021  7018  New England  nwe   h  dal        3.0     3800.0
# 3719     9  2021  7018  New England  nwe   a  car       20.0     4800.0
# 4115    10  2021  7018  New England  nwe   h  cle       11.0     4300.0
#
#       home_dummy  ...   LastCMA  LastSalaryCMA    FDLast3  OpptLast  \
# 1754           1  ...  9.000000    4700.000000   9.000000       3.0
# 2189           0  ...  7.250000    4450.000000   8.000000      23.0
# 2580           1  ...  6.800000    4560.000000   3.333333       2.0
# 3719           0  ...  7.750000    4400.000000   9.333333       3.0
# 4115           1  ...  9.111111    4444.444444  15.000000      -2.0
#
#        OpptAvg3  Def  QB  RB  TE  WR
# 1754   3.666667    1   0   0   0   0
# 2189  12.000000    1   0   0   0   0
# 2580   2.000000    1   0   0   0   0
# 3719  10.000000    1   0   0   0   0
# 4115   4.000000    1   0   0   0   0
#
# [5 rows x 23 columns]

# %%
X_test[X_test['FD salary'] == 4800 ]
# Out:
#       Week  FD salary  home_dummy  LastFD  LastSalary    FDLast3   Salary_MA3  \
# 4229    11     4800.0           1     0.7      6000.0   0.800000  5266.666667
# 4249    11     4800.0           1     2.7      4800.0   3.266667  4966.666667
# 4309    11     4800.0           0     2.0      4700.0   1.500000  4700.000000
# 4374    11     4800.0           1     2.8      4600.0   2.500000  4700.000000
# 4426    11     4800.0           0     0.0      5000.0   4.266667  4833.333333
# 4432    11     4800.0           0     5.7      4700.0   4.600000  4633.333333
# 4456    11     4800.0           0     4.0      4200.0   1.633333  4366.666667
# 4519    11     4800.0           0    11.0      4300.0  14.666667  4633.333333
# 4535    11     4800.0           0    18.0      3300.0  11.666667  4133.333333
#
#        LastCMA  LastSalaryCMA  OpptLast   OpptAvg3  Def  QB  RB  TE  WR
# 4229  0.800000    5266.666667      36.9  26.933333    0   0   1   0   0
# 4249  3.200000    4777.777778      17.1  21.266667    0   0   1   0   0
# 4309  1.566667    4600.000000      12.3   9.500000    0   0   0   0   1
# 4374  3.814286    4757.142857      29.0  27.966667    0   0   0   0   1
# 4426  3.750000    2425.000000      14.9  16.900000    0   0   0   0   1
# 4432  2.922222    4444.444444      17.6  21.200000    0   0   0   1   0
# 4456  0.677778    4066.666667       6.6   6.833333    0   0   0   1   0
# 4519  9.300000    4430.000000      23.0  12.000000    1   0   0   0   0
# 4535  6.200000    3830.000000      12.0   8.000000    1   0   0   0   0

# %%
### Optimal lineup based on predictions??
from pulp import *

def best_lineup(names, positions, salaries, projections):
    
    nplayers = len(names)
    
    prob = pulp.LpProblem("NFL")
    
    lineup = [pulp.LpVariable("Player_{}".format(i), cat='Binary') for i in range(nplayers) ]
    
    # Minimize the negative of the sum of projections of the 9-man roster
    prob += pulp.lpSum( -1 * projections[i] * lineup[i] for i in range(nplayers) )
    
    # Nine Total Players in the Lineup:
    prob += (pulp.lpSum(lineup[i] for i in range(nplayers)) == 9  ) , "Nine Players per Roster"

    QB_indexes   = []
    RB_indexes   = []
    WR_indexes   = []
    TE_indexes   = []
    DST_indexes  = []
    
    for i,item in enumerate(positions):
        if item == "QB":
            QB_indexes += [i]
        elif item =="RB":
            RB_indexes += [i]
        elif item == "WR":
            WR_indexes += [i]
        elif item == "TE":
            TE_indexes += [i]
        elif item == "D":
            DST_indexes += [i]
        else:
            print("Found position: " + item )
    
    prob += (pulp.lpSum( lineup[i] for i in QB_indexes ) == 1) , 'QB Constraint'

    prob += (pulp.lpSum( lineup[i] for i in DST_indexes ) == 1) , 'D Constraint'

    prob += (  pulp.lpSum( lineup[i] for i in RB_indexes ) >= 2) , 'RB Constraint min'
    prob += (  pulp.lpSum( lineup[i] for i in RB_indexes ) <= 3) , 'RB Constraint max'

    prob += (  pulp.lpSum( lineup[i] for i in WR_indexes ) >= 3) , 'WR Constraint min'
    prob += (  pulp.lpSum( lineup[i] for i in WR_indexes ) <= 4) , 'WR Constraint max'

    prob += (  pulp.lpSum( lineup[i] for i in TE_indexes ) >= 1) , 'TE Constraint min'
    prob += (  pulp.lpSum( lineup[i] for i in TE_indexes ) <= 2) , 'TE Constraint max'

    ### Stay under the salary cap:
    prob += (  pulp.lpSum( [lineup[i] * salaries[i] for i in range(nplayers)] ) <= 60000.0 ) , 'Salary Constraint'
    
    prob.solve()
    
    my_indices = []

    for variable in prob.variables():
        if variable.varValue == 1:
            #print( variable.name)
            my_indices.append( int( str.split( variable.name , "_")[1] ) )
    
    print(my_indices)
    
    best_names       = [names[x] for x in my_indices]
    best_positions   = [positions[x] for x in my_indices]
    best_salaries    = [salaries[x] for x in my_indices]
    best_projections = [projections[x] for x in my_indices]
    
    #df = pd.DataFrame({'names':names[my_indices], 'position':positions[my_indices],
    #                   'salary':salaries[my_indices], 'projection':projections[my_indices]
    #                  }  )
    
    df = pd.DataFrame({'names':best_names, 'position':best_positions,
                       'salary':best_salaries, 'projection':best_projections  })
    
    print(df)
    
    return( best_names )

# %%
testDF.head()

testDF['Pos'] = 'MISSING'

testDF.loc[testDF.QB == 1, 'Pos'] = 'QB'
testDF.loc[testDF.Def == 1, 'Pos'] = 'D'
testDF.loc[testDF.RB == 1, 'Pos'] = 'RB'
testDF.loc[testDF.WR == 1, 'Pos'] = 'WR'
testDF.loc[testDF.TE == 1, 'Pos'] = 'TE'

testDF.tail()

testDF.Pos.value_counts()
# Out:
# <ipython-input-63-b5e315cf2639>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testDF['Pos'] = 'MISSING'
# /Users/michaelruston/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /Users/michaelruston/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /Users/michaelruston/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /Users/michaelruston/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /Users/michaelruston/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# WR    122
# RB     81
# TE     70
# QB     29
# D      26
# Name: Pos, dtype: int64

# %%
testDF.head()
# Out:
#       Week  FD salary  Def  QB  RB  TE  WR             Name  FD pred  \
# 4135    11     7700.0    0   1   0   0   0  Herbert, Justin    18.19
# 4136    11     7700.0    0   1   0   0   0   Rodgers, Aaron    17.76
# 4137    11     7700.0    0   1   0   0   0     Hurts, Jalen    18.77
# 4138    11     7000.0    0   1   0   0   0  Siemian, Trevor    13.99
# 4140    11     7400.0    0   1   0   0   0    Cousins, Kirk    16.55
#
#       FD actual Pos
# 4135      35.28  QB
# 4136      33.50  QB
# 4137      30.78  QB
# 4138      26.16  QB
# 4140      25.24  QB

# %%
names = list(testDF.Name)
positions = list(testDF.Pos)
salaries = list(testDF['FD salary'])
projections = list(testDF['FD pred'])

#best_lineup(testDF.Name, testDF.Pos, testDF['FD salary'], testDF['FD pred'])
lu = best_lineup(names, positions, salaries, projections)

#names
#positions
#salaries
#projections
# Out:
# [119, 123, 128, 2, 232, 233, 309, 31, 35]
#             names position  salary  projection
# 0  Williams, Mike       WR  6500.0        9.83
# 1   Samuel, Deebo       WR  7600.0       14.48
# 2     Moore, D.J.       WR  6700.0       10.70
# 3    Hurts, Jalen       QB  7700.0       18.77
# 4      Ertz, Zach       TE  5000.0        5.69
# 5   Kelce, Travis       TE  7300.0       14.35
# 6    Indianapolis        D  3200.0        5.06
# 7      Mixon, Joe       RB  7600.0       14.78
# 8    Cook, Dalvin       RB  8400.0       17.33

# %%
testDF[testDF.Name.isin(lu)]['FD pred'].sum()  ### 110.99

testDF[testDF.Name.isin(lu)]['FD actual'].sum() ### 174.78

testDF[testDF.Name.isin(lu)]['FD salary'].sum() ### 60,000
# Out:
# 60000.0

# %%
### Now what was the actual optimal lineup?
names = list(testDF.Name)
positions = list(testDF.Pos)
salaries = list(testDF['FD salary'])
projections = list(testDF['FD actual'])

#best_lineup(testDF.Name, testDF.Pos, testDF['FD salary'], testDF['FD pred'])
lu = best_lineup(names, positions, salaries, projections)
# Out:
# [0, 110, 112, 113, 114, 232, 29, 30, 302]
#                        names position  salary  projection
# 0            Herbert, Justin       QB  7700.0       35.28
# 1          Jefferson, Justin       WR  7900.0       33.20
# 2              Moore, Elijah       WR  5900.0       25.60
# 3            Mooney, Darnell       WR  6000.0       20.60
# 4  Valdes-Scantling, Marquez       WR  5200.0       20.30
# 5                 Ertz, Zach       TE  5000.0       24.80
# 6           Taylor, Jonathan       RB  8800.0       51.90
# 7             Ekeler, Austin       RB  8200.0       38.50
# 8                New England        D  4800.0       28.00

# %%
testDF[testDF.Name.isin(lu)]['FD pred'].sum() ### 98.25

testDF[testDF.Name.isin(lu)]['FD actual'].sum() ### 278.18

testDF[testDF.Name.isin(lu)]['FD salary'].sum() ### 59,500
# Out:
# 59500.0

# %%
thruweek10[thruweek10.Name == 'Taylor, Jonathan']
# Out:
#       Week  Year   GID              Name Team h/a Oppt  FD points  FD salary  \
# 1368     4  2021  5820  Taylor, Jonathan  ind   a  mia       18.9     6600.0
# 1803     5  2021  5820  Taylor, Jonathan  ind   a  bal       30.4     6900.0
# 2237     6  2021  5820  Taylor, Jonathan  ind   h  hou       28.3     7500.0
# 2990     8  2021  5820  Taylor, Jonathan  ind   h  ten       19.7     8500.0
# 3401     9  2021  5820  Taylor, Jonathan  ind   h  nyj       33.0     9200.0
# 3791    10  2021  5820  Taylor, Jonathan  ind   h  jac       21.6     9400.0
#
#       home_dummy  ...    LastCMA  LastSalaryCMA    FDLast3  OpptLast  \
# 1368           0  ...   9.366667    7366.666667   9.366667      35.5
# 1803           0  ...  11.750000    7175.000000  10.800000      15.1
# 2237           1  ...  15.480000    7120.000000  19.000000      17.2
# 2990           1  ...  17.457143    7414.285714  25.066667      10.4
# 3401           1  ...  17.737500    7550.000000  21.500000      25.7
# 3791           1  ...  19.433333    7733.333333  23.066667      12.8
#
#        OpptAvg3  Def  QB  RB  TE  WR
# 1368  28.633333    0   0   1   0   0
# 1803  20.300000    0   0   1   0   0
# 2237  18.600000    0   0   1   0   0
# 2990  15.666667    0   0   1   0   0
# 3401  37.466667    0   0   1   0   0
# 3791  12.133333    0   0   1   0   0
#
# [6 rows x 23 columns]

# %%
week11[week11.Name == 'Taylor, Jonathan']
# Out:
#       Week  Year   GID              Name Team h/a Oppt  FD points  FD salary  \
# 4173    11  2021  5820  Taylor, Jonathan  ind   a  buf       51.9     8800.0
#
#       home_dummy  ...  LastCMA  LastSalaryCMA    FDLast3  OpptLast   OpptAvg3  \
# 4173           0  ...    19.65         7900.0  24.766667      26.8  15.133333
#
#       Def  QB  RB  TE  WR
# 4173    0   0   1   0   0
#
# [1 rows x 23 columns]

# %%
week11.loc[4173]
# Out:
# Week                           11
# Year                         2021
# GID                          5820
# Name             Taylor, Jonathan
# Team                          ind
# h/a                             a
# Oppt                          buf
# FD points                    51.9
# FD salary                    8800
# home_dummy                      0
# LastFD                       21.6
# LastSalary                   9400
# FD_MA3                       35.5
# Salary_MA3                9133.33
# LastCMA                     19.65
# LastSalaryCMA                7900
# OpptLast                     26.8
# OpptAvg3                  15.1333
# Def                             0
# QB                              0
# RB                              1
# TE                              0
# WR                              0
# Name: 4173, dtype: object
